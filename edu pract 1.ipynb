# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_rows" , 999)

# %%
df = pd.read_csv(r'/home/rahul/eduroids internship/fresh.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2                   Unnamed: 3  \
# 0      S.No.     Reg. ID       Dated           Establishment Name
# 1          1  2009000007  13/11/2009                         Shop
# 2          2  2009000008  13/11/2009  K.d. Pumps & Sanitary Store
# 3          3  2009000010  14/11/2009            Bhola Cycle Works
# 4          4  2009000011  14/11/2009               Sanjay Tailors
#
#                                           Unnamed: 4 Unnamed: 5  \
# 0                                            Address   Category
# 1  Plot No-470,street No.21, Jafrabad Delhi  PIN-...       Shop
# 2  Plot No.470, Street No21 Jafrabad Delhi  PIN-1...       Shop
# 3       1/2140 , East Ram Nagar Shahdara  PIN-110032       Shop
# 4       1/2140 , East Ram Nagar Shahdara  PIN-110032       Shop
#
#                   Unnamed: 6                        Unnamed: 7
# 0         Nature of Business                            Status
# ...

# %%
df.columns =['S.No', 'Reg. ID', 'Dated', 'Establishment Name','Address','Category','Nature of Business','Status']

# %%
df.head()
# Out:
#     S.No     Reg. ID       Dated           Establishment Name  \
# 0  S.No.     Reg. ID       Dated           Establishment Name
# 1      1  2009000007  13/11/2009                         Shop
# 2      2  2009000008  13/11/2009  K.d. Pumps & Sanitary Store
# 3      3  2009000010  14/11/2009            Bhola Cycle Works
# 4      4  2009000011  14/11/2009               Sanjay Tailors
#
#                                              Address  Category  \
# 0                                            Address  Category
# 1  Plot No-470,street No.21, Jafrabad Delhi  PIN-...      Shop
# 2  Plot No.470, Street No21 Jafrabad Delhi  PIN-1...      Shop
# 3       1/2140 , East Ram Nagar Shahdara  PIN-110032      Shop
# 4       1/2140 , East Ram Nagar Shahdara  PIN-110032      Shop
#
#           Nature of Business                            Status
# 0         Nature of Business                            Status
# 1  Pumps & Pumping Equipment  Registration Certificate Issued.
# ...

# %%
dff = df.drop(0)
dff
# Out:
#     S.No     Reg. ID       Dated           Establishment Name  \
# 1      1  2009000007  13/11/2009                         Shop
# 2      2  2009000008  13/11/2009  K.d. Pumps & Sanitary Store
# 3      3  2009000010  14/11/2009            Bhola Cycle Works
# 4      4  2009000011  14/11/2009               Sanjay Tailors
# 5      5  2009000012  14/11/2009           Shivani Cyber Cafe
# ..   ...         ...         ...                          ...
# 96    96  2009000124  17/11/2009  Prakash Air Freight Pvt Ltd
# 97    97  2009000125  17/11/2009              Jagdamba Motors
# 98    98  2009000126  17/11/2009         Subham General Store
# 99    99  2009000127  17/11/2009         Jagdamba Motor Parts
# 100  100  2009000128  17/11/2009  Prakash Air Freight Pvt Ltd
#
#                                                Address  \
# 1    Plot No-470,street No.21, Jafrabad Delhi  PIN-...
# 2    Plot No.470, Street No21 Jafrabad Delhi  PIN-1...
# ...

# %%
dff.describe()
# Out:
#        S.No     Reg. ID       Dated              Establishment Name  \
# count   100         100         100                             100
# unique  100         100           5                              94
# top       1  2009000007  16/11/2009  Univolt Electro Devices Pvt. L
# freq      1           1          46                               3
#
#                                                  Address Category  \
# count                                                100      100
# unique                                                92        4
# top     B-1 Arjun Nagar Safd Encl  New Delhi  PIN-110029     Shop
# freq                                                   4       68
#
#        Nature of Business                            Status
# count                 100                               100
# unique                 42                                 1
# top                Others  Registration Certificate Issued.
# ...

# %%
dff.columns
# Out:
# Index(['S.No', 'Reg. ID', 'Dated', 'Establishment Name', 'Address', 'Category',
#        'Nature of Business', 'Status'],
#       dtype='object')

# %%
dff['Nature of Business'].unique()
# Out:
# array(['Pumps & Pumping Equipment', 'Others',
#        'Computer Hardware & Peripherals',
#        'Electronic Products & Components', 'Consultants & Negotiators',
#        'Auto Parts', 'Hotel & Restaurant', 'Readymade Graments',
#        'Beauty Parlour', 'Boutique', 'Garments Store',
#        'Automotive Parts, Components & Spares', 'Book Publishers',
#        'Food Products', 'Paper Products',
#        'Fire-fighting & Fire Protection Equipment', 'Software',
#        'Interior Decorators/Decorative Items', 'Sweets Shop',
#        'Manpower & Labor Export', 'Yarn', 'Automobile', 'Handicrafts',
#        'Construction Projects', 'General Store',
#        'Air-conditioning & Equipment', 'Textiles',
#        'Automobile Accessories', 'Departmental Store', 'Metals & Alloys',
#        'Jewelry', 'Bakery & Confectioners', 'Bank',
#        'Travel Agents & Tour Operators', 'Bearings', 'Boxes',
#        'Stationery', 'Mutual Funds',
# ...

# %%
plt.figure(figsize=(41,29))
sns.set(style="darkgrid")
sns.scatterplot(x= 'Category' , y = 'Nature of Business', hue='Category',data=dff)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.catplot( y = 'Category', hue='Category',data=dff, kind = "count" ,order=dff['Category'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(30,30))
sns.scatterplot(x='Reg. ID', y='Nature of Business',hue='Category',data=dff)
plt.show()

# %%
plt.figure(figsize=(90,0))
sns.catplot( y = 'Nature of Business' , kind = "count",data = dff)
plt.show()

# %%
#Simple Swarm plot
plt.figure(figsize=(10,10))
sns.swarmplot(dff['Category'], dff['Dated'],size=10)
plt.show()
# Out:
# /home/rahul/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/rahul/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 38.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
dff.columns
# Out:
# Index(['S.No', 'Reg. ID', 'Dated', 'Establishment Name', 'Address', 'Category',
#        'Nature of Business', 'Status'],
#       dtype='object')

# %%
plt.figure(figsize=(70,57))
sns.swarmplot(x= 'Nature of Business', y = 'Reg. ID', hue='Category', size = 8 , data = dff)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
dff["Category_le"] = le.fit_transform(dff["Category"])

# %%
dff["Category_le"].unique()
# Out:
# array([3, 0, 1, 2])

# %%
dff['Nature_of_Business'] = le.fit_transform(dff['Nature of Business'])

# %%
dff[['Nature of Business','Nature_of_Business','Category']]
# Out:
#                             Nature of Business  Nature_of_Business  \
# 1                    Pumps & Pumping Equipment                  33
# 2                    Pumps & Pumping Equipment                  33
# 3                                       Others                  31
# 4                                       Others                  31
# 5              Computer Hardware & Peripherals                  13
# 6              Computer Hardware & Peripherals                  13
# 7             Electronic Products & Components                  18
# 8                    Consultants & Negotiators                  15
# 9                    Consultants & Negotiators                  15
# 10                                  Auto Parts                   1
# 11                          Hotel & Restaurant                  25
# 12                                      Others                  31
# 13                          Readymade Graments                  34
# ...

# %%
 dff["Category_le"].corr(dff['Nature_of_Business'])
# Out:
# -0.029954998641273815

# %%
dff.corr()
# Out:
#                     Category_le  Nature_of_Business
# Category_le            1.000000           -0.029955
# Nature_of_Business    -0.029955            1.000000

# %%
dff.columns
# Out:
# Index(['S.No', 'Reg. ID', 'Dated', 'Establishment Name', 'Address', 'Category',
#        'Nature of Business', 'Status', 'Category_le', 'Nature_of_Business'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
cor = dff.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.title("CoRelation Graph")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Nature_of_Business',y="Category_le",hue='Category',data=dff)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.swarmplot(x='Category' , y = 'Nature of Business', hue='Category_le', size = 8 , data = dff)

plt.show()

# %%
plt.figure(figsize=(16,8))
W = sns.histplot(y = 'Category', x = 'Nature of Business', hue='Category' , data = dff)
W.set_xticklabels(dff["Nature of Business"].unique(), rotation=90)

plt.show()
# Out:
# /tmp/ipykernel_4542/2439713822.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   W.set_xticklabels(dff["Nature of Business"].unique(), rotation=90)
